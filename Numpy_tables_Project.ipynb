# %% [markdown]
# # Numpy Tables
# **Copyright: © NexStream Technical Institute, LLC**.
# All rights reserved
#
# In this project you'll read a csv file and process it using Numpy Tables.
# See the following link for the API:   http://data8.org/datascience/tables.html
#
# Follow the steps below and record your output - you will need to upload it as part of your assignment.

# %%
#Step 1
#Upload the file burritos_01022018.csv file to your Google Drive.
#Mount your drive and change to the folder. 
#Note if get ERROR:root:Internal Python error in the inspect module error when trying to mount drive, restart runtime
from datascience import *

# Mount drive 
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# %cd /content/drive/My\ Drive/Colab\ Notebooks/....YOUR DRIVE PATH HERE...

# %%
#Note if get ERROR:root:Internal Python error in the inspect module error when trying to mount drive, restart runtime
#If restarted runtime, then execute previous cell!!

#Step 2
#Create a new table called 'burritosInSD' and read the dataset (burritos_01022018.csv)
#Hint - use the 'read_table' function
#Print out the first 5 rows
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.read_table.html?highlight=read_table 
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.show.html#datascience.tables.Table.show
# YOUR CODE HERE...

#Step 3
#Create a function with the API shown which returns the number of rows from the input inTable.
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.num_rows.html#datascience.tables.Table.num_rows
def burritoNumRows(inTable):
# YOUR CODE HERE...

#Step 4
#Create a function with the API shown which returns the number of columns from the input inTable.
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.num_columns.html#datascience.tables.Table.num_columns
def burritoNumCols(inTable):
# YOUR CODE HERE...

#Step 5
#Create a function with the API shown which returns a tuple of the Attributes (label) names from the input inTable.
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.labels.html#datascience.tables.Table.labels
def burritoLabels(inTable):
# YOUR CODE HERE...

#Step 6 
#Create a function with the API shown which returns an array of the attribute specified by the input parameter 'label' from the input inTable.
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.column.html#datascience.tables.Table.column
def burritoCosts(inTable, label):
# YOUR CODE HERE...

#Step 7
#Create a function with the API shown which extracts the attribute specified by the input parameter 'label' from the input inTable and returns it in a new table. 
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.select.html#datascience.tables.Table.select
def burritoExtract(inTable, label):
# YOUR CODE HERE...

#Step 8
#Create a function with the API shown which returns a new table comprised of the input inTable but with the input parameter 'label' dropped.
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.drop.html#datascience.tables.Table.drop
def burritoSliceOut(inTable, label):
# YOUR CODE HERE...

#Step 9
#Create a function with the API shown which returns a table of the 'expensive' burritos in the input inTable, i.e. burritos with cost above the input integer 'costAbove'.
#Hint - Filter table based on conditional, and use 'are.above' 
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.where.html#datascience.tables.Table.where
def burritosExpensive(inTable, costAbove):
# YOUR CODE HERE...

#Step 10
#Create a function with the API shown which returns a table of the 'cheap' burritos in the input inTable, i.e. burritos with cost below the input integer 'costBelow'.
#Hint - Filter table based on conditional, and use 'are.below'
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.where.html#datascience.tables.Table.where
def burritosCheap(inTable, costBelow):
# YOUR CODE HERE...

#Step 11
#Create a function with the API shown which returns a table of the burritos shops in the input inTable based on the 'neighborhood' input parameter.
#Hint - Filter table based on conditional, and use are.containing
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.where.html#datascience.tables.Table.where
def burritosInTheHood(inTable, neighborhood):
# YOUR CODE HERE...

#Step 12
#Create a function with the API shown which returns a table comprised of the rows from the input inTable based on the 'rowList' input paremeter list.
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.take.html#datascience.tables.Table.take
def burritosGetRows(inTable, rowList):
# YOUR CODE HERE...

#Step 13
#Create a function with the API shown which returns a table from the input inTable with the elements (rows) 
#   sorted in ascending order based on the 'sortBy' input parameter.
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.sort.html#datascience.tables.Table.sort 
def burritosSortedAscending(inTable, sortBy):
# YOUR CODE HERE...

#Step 14
#Create a function with the API shown which returns a table from the input inTable with the elements  
#   sorted in descending order based on the 'sortBy' input parameter.
#Hint - http://data8.org/datascience/_autosummary/datascience.tables.Table.sort.html#datascience.tables.Table.sort 
def burritosSortedDescending(inTable, sortBy):
# YOUR CODE HERE...

#Step 15
#Create a runner program which CALLS THE APPROPRIATE functions and prints out the specified output as indicated below.
#Note:  you will need to copy/screenshot your runner code and upload the output from your console as part of your assignment.
#Note:  your runner must call the functions that you wrote (you cannot hard code the processing here).
#15a:  Print out the number of rows in burritos_01022018.csv
#15b:  Print out the number of columns in burritos_01022018.csv
#15c:  Print out the first 10 attributes (i.e. the column labels) in burritos_01022018.csv
#15d:  Print out the burrito costs from the first 10 entries in burritos_01022018.csv.
#15e:  Print out the first 5 entries of Addresses from burritos_01022018.csv
#15f:  Print out the attributes (column labels) in burritos_01022018.csv after removing the 'Address' and 'URL' data.
#15g:  Print out the Location and costs of burritos from burritos_01022018.csv which are over $8.
#15h:  Print out the Location and costs of burritos from burritos_01022018.csv which are under $6.
#15i:  Print out the type of burrito that is offered from burritos_01022018.csv from all Carlsbad locations.
#15j:  Print out row 35 from burritos_01022018.csv.
#15k:  Print out the costs of burritos in descending order from burritos_01022018.csv at Taco Villa.



#-------------------------------------------------------------------------------------------------
#Test with the following doctest test vectors.
#DO NOT EDIT THE TEST CODE!!!!
#Even changing the spacing can cause errors.
#The test code will automatically execute when you run the cell.
#You should test all your combination of outputs but your code at least must pass these exact tests.
#If your code fails, you will see a description in the console cell.
#If your code passes, you will see the message: "TestResults(failed=0, attempted=6)"

import doctest

"""
  >>> print('Step 3: Number of rows: ', burritoNumRows(burritosInSD))
  Step 3: Number of rows:  385
  >>> print('Step 4: Number of columns: ', burritoNumCols(burritosInSD))
  Step 4: Number of columns:  66
  >>> print('Step 5:  Attributes (first 5): ', burritoLabels(burritosInSD)[0:5])
  Step 5:  Attributes (first 5):  ('Location', 'Burrito', 'Date', 'Neighborhood', 'Address')
  >>> print('Step 6: burritosInSD Costs (first 5):', burritoCosts(burritosInSD, 'Cost')[0:5])
  Step 6: burritosInSD Costs (first 5): [6.49 5.45 4.85 5.25 6.59]
  >>> print('Step 7:  burritoNeighborhoods (first 5):', burritoExtract(burritosInSD, 'Neighborhood').column('Neighborhood')[0:5])
  Step 7:  burritoNeighborhoods (first 5): ['Miramar' 'San Marcos' 'nan' 'nan' 'Carlsbad']
  >>> print('Step 8: burritoNoNeighborhoods (first 10):', burritoSliceOut(burritosInSD, 'Neighborhood').labels[0:10])
  Step 8: burritoNoNeighborhoods (first 10): ('Location', 'Burrito', 'Date', 'Address', 'URL', 'Yelp', 'Google', 'Chips', 'Cost', 'Hunger')
  >>> print('Step 9:  Expensive burritos (first 5):', burritosExpensive(burritosInSD, 10).column('Cost')[0:5])
  Step 9:  Expensive burritos (first 5): [11.75 11.95 11.95 10.5  25.  ]
  >>> print('Step 10:  Cheap burritos (first 4):', burritosCheap(burritosInSD, 5).column('Cost')[0:4], burritosCheap(burritosInSD, 5).column('Location')[0:4])
  Step 10:  Cheap burritos (first 4): [4.85 3.5  4.87 4.87] ["Oscar's Mexican food" "Lolita's Taco shop" 'El Nopalito ' 'El Nopalito ']
  >>> print('Step 11:  Burritos Locations in Carlsbad:', burritosInTheHood(burritosInSD, 'Carlsbad').column('Location')[0:])
  Step 11:  Burritos Locations in Carlsbad: ['Pollos Maria' "Lola's 7 Up Market & Deli" "Senor Grubby's" 'Chipotle']
  >>> print('Step 12:  Rows 1, 17, 47:', burritosGetRows(burritosInSD, [1,17,47]).column('Location')[0:])
  Step 12:  Rows 1, 17, 47: ["Oscar's Mexican food" "Graciela's Taco Shop" 'Vallarta express']
  >>> print('Step 13:  Location with Burritos Sorted by Cost, Ascending order (first 3):', burritosSortedAscending(burritosInSD, 'Cost').column('Location')[0:3])
  Step 13:  Location with Burritos Sorted by Cost, Ascending order (first 3): ['MXN on Washington' "Lolita's Taco shop" 'Lucha Libre North Park']
  >>> print('Step 14a:  Location of Burrito shops Sorted by Cost, Descending order (first 3):', burritosSortedDescending(burritosInSD, 'Cost').column('Location')[0:3])
  Step 14a:  Location of Burrito shops Sorted by Cost, Descending order (first 3): ['Taco Villa' 'Taco Villa' 'Taco Villa']
  >>> print('Step 14b:  Costs of Burritos at locations sorted by cost, Descending order (first 3):', burritosSortedDescending(burritosInSD, 'Cost').column('Cost')[0:3])
  Step 14b:  Costs of Burritos at locations sorted by cost, Descending order (first 3): [nan nan nan]

"""

doctest.testmod()
